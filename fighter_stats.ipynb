# %%
import sys
import pymongo
import pandas as pd

# %%
myclient = pymongo.MongoClient("mongodb+srv://mel518:databasepass@TestTrain.ppavz.mongodb.net/Project4?retryWrites=true&w=majority")
mydb = myclient["Project4"]
mycol = mydb["Data"]

myquery = { "Winner": "Red" }

mydoc = mycol.find(myquery)

# %%
df = pd.DataFrame(mydoc)
df = df.sort_values('date', ascending=False)
df.head()
# Out:
#                          _id  level_0  index       R_fighter      B_fighter  \
# 0   629ba614ce24e88d2d20b1d3        7      7   Derek Brunson  Kevin Holland
# 24  629ba614ce24e88d2d20b1d4        8      8  Montel Jackson  Jesse Strader
# 23  629ba614ce24e88d2d20b1cd        1      1    Trevin Giles  Roman Dolidze
# 22  629ba614ce24e88d2d20b1cc        0      0    Adrian Yanez  Gustavo Lopez
# 11  629ba614ce24e88d2d20b1d5        9      9     Bruno Silva        JP Buys
#
#            Referee        date                location Winner  title_bout  \
# 0        Herb Dean  2021-03-20  Las Vegas, Nevada, USA    Red       False
# 24  Keith Peterson  2021-03-20  Las Vegas, Nevada, USA    Red       False
# 23       Herb Dean  2021-03-20  Las Vegas, Nevada, USA    Red       False
# 22   Chris Tognoni  2021-03-20  Las Vegas, Nevada, USA    Red       False
# 11      Mark Smith  2021-03-20  Las Vegas, Nevada, USA    Red       False
#
# ...

# %%
with pd.option_context("display.max_columns", None):
    display(df)
# Out:
#                            _id  level_0  index       R_fighter  \
# 0     629ba614ce24e88d2d20b1d3        7      7   Derek Brunson
# 24    629ba614ce24e88d2d20b1d4        8      8  Montel Jackson
# 23    629ba614ce24e88d2d20b1cd        1      1    Trevin Giles
# 22    629ba614ce24e88d2d20b1cc        0      0    Adrian Yanez
# 11    629ba614ce24e88d2d20b1d5        9      9     Bruno Silva
# ...                        ...      ...    ...             ...
# 3950  629ba614ce24e88d2d20c944     6008   6008    Orlando Wiet
# 3937  629ba614ce24e88d2d20c93f     6003   6003    Royce Gracie
# 3934  629ba614ce24e88d2d20c93a     5998   5998   Patrick Smith
# 3936  629ba614ce24e88d2d20c93c     6000   6000   Remco Pardoel
# 3938  629ba614ce24e88d2d20c947     6011   6011    Scott Morris
#
#              B_fighter         Referee        date                location  \
# 0        Kevin Holland       Herb Dean  2021-03-20  Las Vegas, Nevada, USA
# ...

# %%
dfblue = df[['_id',
 'B_fighter',
 'Referee',
 'date',
 'location',
 'Winner',
 'title_bout',
 'weight_class',
 'B_avg_KD',
 'B_avg_opp_KD',
 'B_avg_SIG_STR_pct',
 'B_avg_opp_SIG_STR_pct',
 'B_avg_TD_pct',
 'B_avg_opp_TD_pct',
 'B_avg_SUB_ATT',
 'B_avg_opp_SUB_ATT',
 'B_avg_REV',
 'B_avg_opp_REV',
 'B_avg_SIG_STR_att',
 'B_avg_SIG_STR_landed',
 'B_avg_opp_SIG_STR_att',
 'B_avg_opp_SIG_STR_landed',
 'B_avg_TOTAL_STR_att',
 'B_avg_TOTAL_STR_landed',
 'B_avg_opp_TOTAL_STR_att',
 'B_avg_opp_TOTAL_STR_landed',
 'B_avg_TD_att',
 'B_avg_TD_landed',
 'B_avg_opp_TD_att',
 'B_avg_opp_TD_landed',
 'B_avg_HEAD_att',
 'B_avg_HEAD_landed',
 'B_avg_opp_HEAD_att',
 'B_avg_opp_HEAD_landed',
 'B_avg_BODY_att',
 'B_avg_BODY_landed',
 'B_avg_opp_BODY_att',
 'B_avg_opp_BODY_landed',
 'B_avg_LEG_att',
 'B_avg_LEG_landed',
 'B_avg_opp_LEG_att',
 'B_avg_opp_LEG_landed',
 'B_avg_DISTANCE_att',
 'B_avg_DISTANCE_landed',
 'B_avg_opp_DISTANCE_att',
 'B_avg_opp_DISTANCE_landed',
 'B_avg_CLINCH_att',
 'B_avg_CLINCH_landed',
 'B_avg_opp_CLINCH_att',
 'B_avg_opp_CLINCH_landed',
 'B_avg_GROUND_att',
 'B_avg_GROUND_landed',
 'B_avg_opp_GROUND_att',
 'B_avg_opp_GROUND_landed',
 'B_avg_CTRL_time(seconds)',
 'B_avg_opp_CTRL_time(seconds)',
 'B_total_time_fought(seconds)',
 'B_total_rounds_fought',
 'B_total_title_bouts',
 'B_current_win_streak',
 'B_current_lose_streak',
 'B_longest_win_streak',
 'B_wins',
 'B_losses',
 'B_draw',
 'B_win_by_Decision_Majority',
 'B_win_by_Decision_Split',
 'B_win_by_Decision_Unanimous',
 'B_win_by_KO/TKO',
 'B_win_by_Submission',
 'B_win_by_TKO_Doctor_Stoppage',
 'B_Stance',
 'B_Height_cms','B_Reach_cms','B_Weight_lbs','B_age']]

# %%
dfblue
# Out:
#                            _id         B_fighter         Referee        date  \
# 0     629ba614ce24e88d2d20b1d3     Kevin Holland       Herb Dean  2021-03-20
# 24    629ba614ce24e88d2d20b1d4     Jesse Strader  Keith Peterson  2021-03-20
# 23    629ba614ce24e88d2d20b1cd     Roman Dolidze       Herb Dean  2021-03-20
# 22    629ba614ce24e88d2d20b1cc     Gustavo Lopez   Chris Tognoni  2021-03-20
# 11    629ba614ce24e88d2d20b1d5           JP Buys      Mark Smith  2021-03-20
# ...                        ...               ...             ...         ...
# 3950  629ba614ce24e88d2d20c944  Robert Lucarelli   John McCarthy  1994-03-11
# 3937  629ba614ce24e88d2d20c93f   Minoki Ichihara   John McCarthy  1994-03-11
# 3934  629ba614ce24e88d2d20c93a      Scott Morris   John McCarthy  1994-03-11
# 3936  629ba614ce24e88d2d20c93c      Orlando Wiet   John McCarthy  1994-03-11
# 3938  629ba614ce24e88d2d20c947    Sean Daugherty   John McCarthy  1994-03-11
#
# ...

# %%
dfred = df[['_id',
 'R_fighter',
 'Referee',
 'date',
 'location',
 'Winner',
 'title_bout',
 'weight_class',
 'R_avg_KD',
 'R_avg_opp_KD',
 'R_avg_SIG_STR_pct',
 'R_avg_opp_SIG_STR_pct',
 'R_avg_TD_pct',
 'R_avg_opp_TD_pct',
 'R_avg_SUB_ATT',
 'R_avg_opp_SUB_ATT',
 'R_avg_REV',
 'R_avg_opp_REV',
 'R_avg_SIG_STR_att',
 'R_avg_SIG_STR_landed',
 'R_avg_opp_SIG_STR_att',
 'R_avg_opp_SIG_STR_landed',
 'R_avg_TOTAL_STR_att',
 'R_avg_TOTAL_STR_landed',
 'R_avg_opp_TOTAL_STR_att',
 'R_avg_opp_TOTAL_STR_landed',
 'R_avg_TD_att',
 'R_avg_TD_landed',
 'R_avg_opp_TD_att',
 'R_avg_opp_TD_landed',
 'R_avg_HEAD_att',
 'R_avg_HEAD_landed',
 'R_avg_opp_HEAD_att',
 'R_avg_opp_HEAD_landed',
 'R_avg_BODY_att',
 'R_avg_BODY_landed',
 'R_avg_opp_BODY_att',
 'R_avg_opp_BODY_landed',
 'R_avg_LEG_att',
 'R_avg_LEG_landed',
 'R_avg_opp_LEG_att',
 'R_avg_opp_LEG_landed',
 'R_avg_DISTANCE_att',
 'R_avg_DISTANCE_landed',
 'R_avg_opp_DISTANCE_att',
 'R_avg_opp_DISTANCE_landed',
 'R_avg_CLINCH_att',
 'R_avg_CLINCH_landed',
 'R_avg_opp_CLINCH_att',
 'R_avg_opp_CLINCH_landed',
 'R_avg_GROUND_att',
 'R_avg_GROUND_landed',
 'R_avg_opp_GROUND_att',
 'R_avg_opp_GROUND_landed',
 'R_avg_CTRL_time(seconds)',
 'R_avg_opp_CTRL_time(seconds)',
 'R_total_time_fought(seconds)',
 'R_total_rounds_fought',
 'R_total_title_bouts',
 'R_current_win_streak',
 'R_current_lose_streak',
 'R_longest_win_streak',
 'R_wins',
 'R_losses',
 'R_draw',
 'R_win_by_Decision_Majority',
 'R_win_by_Decision_Split',
 'R_win_by_Decision_Unanimous',
 'R_win_by_KO/TKO',
 'R_win_by_Submission',
 'R_win_by_TKO_Doctor_Stoppage',
 'R_Stance',
 'R_Height_cms',
 'R_Reach_cms',
 'R_Weight_lbs','R_age']]
dfred
# Out:
#                            _id       R_fighter         Referee        date  \
# 0     629ba614ce24e88d2d20b1d3   Derek Brunson       Herb Dean  2021-03-20
# 24    629ba614ce24e88d2d20b1d4  Montel Jackson  Keith Peterson  2021-03-20
# 23    629ba614ce24e88d2d20b1cd    Trevin Giles       Herb Dean  2021-03-20
# 22    629ba614ce24e88d2d20b1cc    Adrian Yanez   Chris Tognoni  2021-03-20
# 11    629ba614ce24e88d2d20b1d5     Bruno Silva      Mark Smith  2021-03-20
# ...                        ...             ...             ...         ...
# 3950  629ba614ce24e88d2d20c944    Orlando Wiet   John McCarthy  1994-03-11
# 3937  629ba614ce24e88d2d20c93f    Royce Gracie   John McCarthy  1994-03-11
# 3934  629ba614ce24e88d2d20c93a   Patrick Smith   John McCarthy  1994-03-11
# 3936  629ba614ce24e88d2d20c93c   Remco Pardoel   John McCarthy  1994-03-11
# 3938  629ba614ce24e88d2d20c947    Scott Morris   John McCarthy  1994-03-11
#
# ...

# %%
dfred.columns = dfred.columns.str.replace('R_', '')
dfred.columns = dfred.columns.str.replace('B_', '')
dfblue.columns = dfblue.columns.str.replace('B_', '')
dfblue.columns = dfblue.columns.str.replace('R_', '')

# %%
dfred
dfblue
# Out:
#                            _id           fighter         Referee        date  \
# 0     629ba614ce24e88d2d20b1d3     Kevin Holland       Herb Dean  2021-03-20
# 24    629ba614ce24e88d2d20b1d4     Jesse Strader  Keith Peterson  2021-03-20
# 23    629ba614ce24e88d2d20b1cd     Roman Dolidze       Herb Dean  2021-03-20
# 22    629ba614ce24e88d2d20b1cc     Gustavo Lopez   Chris Tognoni  2021-03-20
# 11    629ba614ce24e88d2d20b1d5           JP Buys      Mark Smith  2021-03-20
# ...                        ...               ...             ...         ...
# 3950  629ba614ce24e88d2d20c944  Robert Lucarelli   John McCarthy  1994-03-11
# 3937  629ba614ce24e88d2d20c93f   Minoki Ichihara   John McCarthy  1994-03-11
# 3934  629ba614ce24e88d2d20c93a      Scott Morris   John McCarthy  1994-03-11
# 3936  629ba614ce24e88d2d20c93c      Orlando Wiet   John McCarthy  1994-03-11
# 3938  629ba614ce24e88d2d20c947    Sean Daugherty   John McCarthy  1994-03-11
#
# ...

# %%
dfunion= dfred.append(dfblue)
dfunion.reset_index().drop(columns="index")
dfunion.head()
# Out:
#                          _id         fighter         Referee        date  \
# 0   629ba614ce24e88d2d20b1d3   Derek Brunson       Herb Dean  2021-03-20
# 24  629ba614ce24e88d2d20b1d4  Montel Jackson  Keith Peterson  2021-03-20
# 23  629ba614ce24e88d2d20b1cd    Trevin Giles       Herb Dean  2021-03-20
# 22  629ba614ce24e88d2d20b1cc    Adrian Yanez   Chris Tognoni  2021-03-20
# 11  629ba614ce24e88d2d20b1d5     Bruno Silva      Mark Smith  2021-03-20
#
#                   location Winner  title_bout  weight_class    avg_KD  \
# 0   Las Vegas, Nevada, USA    Red       False  Middleweight  0.024551
# 24  Las Vegas, Nevada, USA    Red       False  Bantamweight  0.750000
# 23  Las Vegas, Nevada, USA    Red       False  Middleweight  1.031250
# 22  Las Vegas, Nevada, USA    Red       False  Bantamweight  1.000000
# 11  Las Vegas, Nevada, USA    Red       False     Flyweight  0.000000
#
#     avg_opp_KD  ...  win_by_Decision_Split  win_by_Decision_Unanimous  \
# ...

# %%
with pd.option_context("display.max_columns", None):
    display(dfunion)
# Out:
#                            _id           fighter         Referee        date  \
# 0     629ba614ce24e88d2d20b1d3     Derek Brunson       Herb Dean  2021-03-20
# 24    629ba614ce24e88d2d20b1d4    Montel Jackson  Keith Peterson  2021-03-20
# 23    629ba614ce24e88d2d20b1cd      Trevin Giles       Herb Dean  2021-03-20
# 22    629ba614ce24e88d2d20b1cc      Adrian Yanez   Chris Tognoni  2021-03-20
# 11    629ba614ce24e88d2d20b1d5       Bruno Silva      Mark Smith  2021-03-20
# ...                        ...               ...             ...         ...
# 3950  629ba614ce24e88d2d20c944  Robert Lucarelli   John McCarthy  1994-03-11
# 3937  629ba614ce24e88d2d20c93f   Minoki Ichihara   John McCarthy  1994-03-11
# 3934  629ba614ce24e88d2d20c93a      Scott Morris   John McCarthy  1994-03-11
# 3936  629ba614ce24e88d2d20c93c      Orlando Wiet   John McCarthy  1994-03-11
# 3938  629ba614ce24e88d2d20c947    Sean Daugherty   John McCarthy  1994-03-11
#
# ...

# %%
sorted_data = dfunion.sort_values('date', ascending=False).drop_duplicates('fighter', keep='first')
sorted_data.head()
# Out:
#                          _id          fighter         Referee        date  \
# 0   629ba614ce24e88d2d20b1d3    Derek Brunson       Herb Dean  2021-03-20
# 24  629ba614ce24e88d2d20b1d4   Montel Jackson  Keith Peterson  2021-03-20
# 20  629ba614ce24e88d2d20b1ce  Harry Hunsucker       Herb Dean  2021-03-20
# 11  629ba614ce24e88d2d20b1d5          JP Buys      Mark Smith  2021-03-20
# 22  629ba614ce24e88d2d20b1cc    Gustavo Lopez   Chris Tognoni  2021-03-20
#
#                   location Winner  title_bout  weight_class    avg_KD  \
# 0   Las Vegas, Nevada, USA    Red       False  Middleweight  0.024551
# 24  Las Vegas, Nevada, USA    Red       False  Bantamweight  0.750000
# 20  Las Vegas, Nevada, USA    Red       False   Heavyweight       NaN
# 11  Las Vegas, Nevada, USA    Red       False     Flyweight       NaN
# 22  Las Vegas, Nevada, USA    Red       False  Bantamweight  0.000000
#
#     avg_opp_KD  ...  win_by_Decision_Split  win_by_Decision_Unanimous  \
# ...

# %%
sorted_data[sorted_data.fighter=='Conor McGregor']
# Out:
#                          _id         fighter    Referee        date  \
# 59  629ba614ce24e88d2d20b221  Conor McGregor  Herb Dean  2021-01-23
#
#                                       location Winner  title_bout  \
# 59  Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
#
#    weight_class    avg_KD  avg_opp_KD  ...  win_by_Decision_Split  \
# 59  Lightweight  1.093262         0.0  ...                      0
#
#     win_by_Decision_Unanimous  win_by_KO/TKO  win_by_Submission  \
# 59                          1              8                  0
#
#     win_by_TKO_Doctor_Stoppage    Stance  Height_cms  Reach_cms  Weight_lbs  \
# 59                           0  Southpaw      175.26     187.96       155.0
#
#      age
# 59  32.0
#
# [1 rows x 76 columns]

# %%
fighter_stats = dfunion[['fighter','date','weight_class','avg_KD','avg_SIG_STpct','avg_TD_pct', 
'avg_SUATT','avg_CTRL_time(seconds)','wins','losses','draw','win_by_Decision_Majority',
'win_by_Decision_Split','win_by_Decision_Unanimous','win_by_KO/TKO','win_by_Submission',
'win_by_TKO_Doctor_Stoppage','Stance','Height_cms','Reach_cms','Weight_lbs','age']]
fighter_stats['fighter'].nunique()
fighter_stats.sort_values('date', ascending=False)
# Out:
#               fighter        date  weight_class    avg_KD  avg_SIG_STpct  \
# 0       Derek Brunson  2021-03-20  Middleweight  0.024551       0.515636
# 24     Montel Jackson  2021-03-20  Bantamweight  0.750000       0.615000
# 20    Harry Hunsucker  2021-03-20   Heavyweight       NaN            NaN
# 11            JP Buys  2021-03-20     Flyweight       NaN            NaN
# 22      Gustavo Lopez  2021-03-20  Bantamweight  0.000000       0.420000
# ...               ...         ...           ...       ...            ...
# 3945    Frank Hamaker  1994-03-11    OpenWeight       NaN            NaN
# 3957    Johnny Rhodes  1994-03-11    OpenWeight  0.000000       0.640000
# 3956     Royce Gracie  1994-03-11    OpenWeight  0.000000       0.250000
# 3967    Patrick Smith  1994-03-11    OpenWeight  0.000000       1.000000
# 3938   Sean Daugherty  1994-03-11    OpenWeight       NaN            NaN
#
#       avg_TD_pct  avg_SUATT  avg_CTRL_time(seconds)  wins  losses  ...  \
# ...

# %%
# fighter_stats.dropna(axis='rows')

# %%
fighter_stats[fighter_stats.fighter=='Conor McGregor']
# Out:
#              fighter        date   weight_class    avg_KD  avg_SIG_STpct  \
# 326   Conor McGregor  2020-01-18   Welterweight  1.186523       0.543848
# 1759  Conor McGregor  2015-01-18  Featherweight  0.875000       0.362500
# 1834  Conor McGregor  2014-07-19  Featherweight  0.500000       0.470000
# 2057  Conor McGregor  2013-08-17  Featherweight  1.000000       0.600000
# 59    Conor McGregor  2021-01-23    Lightweight  1.093262       0.636924
# 637   Conor McGregor  2018-10-06    Lightweight  2.373047       0.467695
#
#       avg_TD_pct  avg_SUATT  avg_CTRL_time(seconds)  wins  losses  ...  \
# 326     0.002734        0.0               28.063477     9       2  ...
# 1759    0.350000        0.0               86.125000     4       0  ...
# 1834    0.400000        0.0              196.500000     2       0  ...
# 2057    0.000000        0.0                5.000000     1       0  ...
# 59      0.001367        0.0               20.531738    10       2  ...
# ...

# %%
# sorted_data = fighter_stats.sort_values('date', ascending=False).drop_duplicates('fighter', keep='first')
# sorted_data
# Out:
#               fighter        date  weight_class    avg_KD  avg_SIG_STpct  \
# 0       Derek Brunson  2021-03-20  Middleweight  0.024551       0.515636
# 24     Montel Jackson  2021-03-20  Bantamweight  0.750000       0.615000
# 20    Harry Hunsucker  2021-03-20   Heavyweight       NaN            NaN
# 11            JP Buys  2021-03-20     Flyweight       NaN            NaN
# 22      Gustavo Lopez  2021-03-20  Bantamweight  0.000000       0.420000
# ...               ...         ...           ...       ...            ...
# 3972       Ray Wizard  1994-03-11    OpenWeight       NaN            NaN
# 3977    David Levicki  1994-03-11    OpenWeight       NaN            NaN
# 3970      Scott Baker  1994-03-11    OpenWeight       NaN            NaN
# 3945    Frank Hamaker  1994-03-11    OpenWeight       NaN            NaN
# 3938   Sean Daugherty  1994-03-11    OpenWeight       NaN            NaN
#
#       avg_TD_pct  avg_SUATT  avg_CTRL_time(seconds)  wins  losses  ...  \
# ...

# %%
sorted_data[sorted_data.fighter=='Conor McGregor']
# Out:
#            fighter        date weight_class    avg_KD  avg_SIG_STpct  \
# 59  Conor McGregor  2021-01-23  Lightweight  1.093262       0.636924
#
#     avg_TD_pct  avg_SUATT  avg_CTRL_time(seconds)  wins  losses  ...  \
# 59    0.001367        0.0               20.531738    10       2  ...
#
#     win_by_Decision_Split  win_by_Decision_Unanimous  win_by_KO/TKO  \
# 59                      0                          1              8
#
#     win_by_Submission  win_by_TKO_Doctor_Stoppage    Stance  Height_cms  \
# 59                  0                           0  Southpaw      175.26
#
#    Reach_cms  Weight_lbs   age
# 59    187.96       155.0  32.0
#
# [1 rows x 22 columns]

# %%
# test = fighter_stats[~(fighter_stats['date'] < '2021-03-01')]
# test.head()

# %%
import json
json_string = fighter_stats.to_json(orient='records')
# json_datafile = json.dumps(json_string, indent =4)

# %%
# Using a JSON string
with open('json_stats_data.json', 'w') as outfile:
    outfile.write(json_string)
