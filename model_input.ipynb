# %%
import pymongo
import pandas as pd

# %%
myclient = pymongo.MongoClient("mongodb+srv://mel518:databasepass@TestTrain.ppavz.mongodb.net/?retryWrites=true&w=majority")
mydb = myclient["Project4"]
mycol = mydb["Combined_Fighter"]
mydoc = mycol.find()
x = pd.DataFrame(mydoc)
recent_stats = x.sort_values('date', ascending=False).drop_duplicates('fighter', keep='first')
recent_stats.drop(columns = ['Referee', 'date', 'location','weight_class', 'Unnamed: 0', 'title_bout', 'Winner', 'age','ifor'], inplace=True)
recent_stats.fillna(0, inplace=True)
recent_stats
# Out:
#                             _id          fighter    avg_KD  avg_opp_KD  \
# 0      62a0c1b7f298a9905b7a0032    Cheyanne Buys  0.000000      0.0000
# 6179   62a0c1b7f298a9905b7a17b4          JP Buys  0.000000      0.0000
# 1      62a0c1b7f298a9905b7a0031      Tai Tuivasa  0.546875      0.1875
# 6049   62a0c1b7f298a9905b7a17ad  Harry Hunsucker  0.000000      0.0000
# 6050   62a0c1b7f298a9905b7a17b2    Kevin Holland  0.156250      0.0000
# ...                         ...              ...       ...         ...
# 11661  62a0c1b7f298a9905b7a2f1d      Fred Ettish  0.000000      0.0000
# 11662  62a0c1b7f298a9905b7a2f1e  Minoki Ichihara  0.000000      0.0000
# 11664  62a0c1b7f298a9905b7a2f21      Scott Baker  0.000000      0.0000
# 11665  62a0c1b7f298a9905b7a2f25       Ray Wizard  0.000000      0.0000
# 11954  62a0c1b7f298a9905b7a2f1f  Thaddeus Luster  0.000000      0.0000
#
#        avg_SIG_STpct  avg_opp_SIG_STpct  avg_TD_pct  avg_opp_TD_pct  \
# 0           0.000000           0.000000    0.000000        0.000000
# 6179        0.000000           0.000000    0.000000        0.000000
# 1           0.538906           0.598594    0.000000        0.312500
# 6049        0.000000           0.000000    0.000000        0.000000
# 6050        0.791582           0.850586    0.269199        0.393398
# ...              ...                ...         ...             ...
# 11661       0.000000           0.000000    0.000000        0.000000
# 11662       0.000000           0.000000    0.000000        0.000000
# 11664       0.000000           0.000000    0.000000        0.000000
# 11665       0.000000           0.000000    0.000000        0.000000
# 11954       0.000000           0.000000    0.000000        0.000000
#
#        avg_SUATT  avg_opp_SUATT  ...  win_by_Decision_Majority  \
# 0       0.000000       0.000000  ...                         0
# 6179    0.000000       0.000000  ...                         0
# 1       0.000000       0.250000  ...                         0
# 6049    0.000000       0.000000  ...                         0
# 6050    0.029297       0.080078  ...                         0
# ...          ...            ...  ...                       ...
# 11661   0.000000       0.000000  ...                         0
# 11662   0.000000       0.000000  ...                         0
# 11664   0.000000       0.000000  ...                         0
# 11665   0.000000       0.000000  ...                         0
# 11954   0.000000       0.000000  ...                         0
#
#        win_by_Decision_Split  win_by_Decision_Unanimous  win_by_KO/TKO  \
# 0                          0                          0              0
# 6179                       0                          0              0
# 1                          0                          1              3
# 6049                       0                          0              0
# 6050                       2                          1              3
# ...                      ...                        ...            ...
# 11661                      0                          0              0
# 11662                      0                          0              0
# 11664                      0                          0              0
# 11665                      0                          0              0
# 11954                      0                          0              0
#
#        win_by_Submission  win_by_TKO_Doctor_Stoppage    Stance  Height_cms  \
# 0                      0                           0    Switch      160.02
# 6179                   0                           0  Orthodox      165.10
# 1                      0                           0  Southpaw      187.96
# 6049                   0                           0  Orthodox      187.96
# 6050                   2                           0  Orthodox      190.50
# ...                  ...                         ...       ...         ...
# 11661                  0                           0  Southpaw      182.88
# 11662                  0                           0  Orthodox      170.18
# 11664                  0                           0         0      182.88
# 11665                  0                           0         0        0.00
# 11954                  0                           0         0      190.50
#
#        Reach_cms  Weight_lbs
# 0         160.02       115.0
# 6179      170.18       125.0
# 1         190.50       264.0
# 6049      190.50       241.0
# 6050      205.74       185.0
# ...          ...         ...
# 11661       0.00       180.0
# 11662       0.00       178.0
# 11664       0.00       210.0
# 11665       0.00         0.0
# 11954       0.00       210.0
#
# [2139 rows x 69 columns]

# %%
collection = mydb['recent_matches']
data_dict = recent_stats.to_dict('records')
# Insert collection
collection.insert_many(data_dict)

# %%
# Two user inputs
first_selection = "Tai Tuivasa"
second_selection = "Kevin Holland"
